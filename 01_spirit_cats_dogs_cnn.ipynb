# %% [markdown]
# <a href="https://colab.research.google.com/github/mahtabb90/cats-dogs-cnn-classifier/blob/spirit/01_spirit_cats_dogs_cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =========================
# CELL 1: CHECK GPU
# =========================
# Syfte:
# Kontrollera att Colab använder GPU.
# CNN tränar mycket snabbare med GPU än på din egen dator.

import tensorflow as tf

print("TensorFlow version:", tf.__version__)
print("GPU available:", tf.config.list_physical_devices("GPU"))
# Out:
# TensorFlow version: 2.20.0
# GPU available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# =========================
# CELL 2: LOAD CATS VS DOGS DATASET
# =========================
# Syfte:
# Vi laddar ett färdigt cats/dogs dataset via TensorFlow Datasets.
# Detta gör att vi slipper Kaggle-token och manuell nedladdning.

import tensorflow_datasets as tfds

(ds_train, ds_val), ds_info = tfds.load(
    "cats_vs_dogs",
    split=["train[:80%]", "train[80%:]"],
    as_supervised=True,
    with_info=True
)

print(ds_info)
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/cats_vs_dogs/4.0.1 has no dataset_info.json
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/1 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# WARNING:absl:1738 images were corrupted and were skipped
# Shuffling /root/tensorflow_datasets/cats_vs_dogs/incomplete.B5Q4CT_4.0.1/cats_vs_dogs-train.tfrecord-[0-9][0-9…
# Dataset cats_vs_dogs downloaded and prepared to /root/tensorflow_datasets/cats_vs_dogs/4.0.1. Subsequent calls will reuse this data.
# tfds.core.DatasetInfo(
#     name='cats_vs_dogs',
#     full_name='cats_vs_dogs/4.0.1',
#     description="""
#     A large set of images of cats and dogs. There are 1738 corrupted images that are dropped.
#     """,
#     homepage='https://www.microsoft.com/en-us/download/details.aspx?id=54765',
#     data_dir='/root/tensorflow_datasets/cats_vs_dogs/4.0.1',
# ...
